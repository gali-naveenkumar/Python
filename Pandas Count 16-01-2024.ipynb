# %% [markdown]
# # Pandas Cont

# %%
import pandas as pd
# to avoid error messages
import warnings
warnings.filterwarnings("ignore")

# %%
# to Read a Csv File
df = pd.read_csv("A:/Data Anlayst Course/Python/Dataset/dirtydata.csv")
display(df)
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           dayone        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         dAYtHREE        60  '2020/12/03'    103       135            340.0
# 3          DayFour        45  '2020/12/04'    109       175            282.4
# 4          Dayfour        45  '2020/12/04'    109       175            282.4
# 5          DayFive        45  '2020/12/05'    117       148            406.0
# 6           DaySix        60  '2020/12/06'    102       127            300.0
# 7         Dayseven        60  '2020/12/07'    110       136            374.0
# 8         dayeiGht       450  '2020/12/08'    104       134            253.3
# 9          DayNine        30  '2020/12/09'    109       133            195.1
# 10          DayTEN        60  '2020/12/10'     98       124            269.0
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
# to know the columns
df.columns
# Out:
# Index(['Day', 'Duration', 'Date', 'Pulse', 'Maxpulse', 'RunningCalories',
#        'Exercise Calories'],
#       dtype='object')

# %%
# total number of columns
len(df.columns)
# Out:
# 7

# %%
# total number of rows
len(df)
# Out:
# 34

# %%
# to know the shpae of the dataframe
df.shape
# Out:
# (34, 7)

# %%
# to know the datatype of each column
df.dtypes
# Out:
# Day                   object
# Duration               int64
# Date                  object
# Pulse                  int64
# Maxpulse               int64
# RunningCalories      float64
# Exercise Calories    float64
# dtype: object

# %%
# to know the file size
import os.path
print(os.path.getsize("A:/Data Anlayst Course/Python/Dataset/dirtydata.csv"))
# Out:
# 1549

# %%
# to get all information of a dataframe in a single output
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Day                34 non-null     object
#  1   Duration           34 non-null     int64
#  2   Date               33 non-null     object
#  3   Pulse              34 non-null     int64
#  4   Maxpulse           34 non-null     int64
#  5   RunningCalories    31 non-null     float64
#  6   Exercise Calories  30 non-null     float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 2.0+ KB

# %%
# to fetch first five rows
df.head()
# Out:
#         Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0    dayone        60  '2020/12/01'    110       130            409.1
# 1    DAYTWO        60  '2020/12/02'    117       145            479.0
# 2  dAYtHREE        60  '2020/12/03'    103       135            340.0
# 3   DayFour        45  '2020/12/04'    109       175            282.4
# 4   Dayfour        45  '2020/12/04'    109       175            282.4
#
#    Exercise Calories
# 0              169.0
# 1              198.0
# 2                NaN
# 3              185.0
# 4              131.0

# %%
# to fetch last five rows
df.tail()
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 29  daytwentyseven        60  '2020/12/27'     92       118            241.0
# 30  DAYTWENTYEIGHT        60  '2020/12/28'    103       132              NaN
# 31   DAYTWENTYNINE        60  '2020/12/29'    100       132            280.0
# 32       DAYTHIRTY        60  '2020/12/30'    102       129            380.3
# 33  dAYtHIRTYfIRST        60  '2020/12/31'     92       115            243.0
#
#     Exercise Calories
# 29              174.0
# 30                NaN
# 31              109.0
# 32              170.0
# 33              119.0

# %%
# to fetch 10 random records from the dataframe
df.sample(10)
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 28    daytwentysix        60      20201226    100       120            250.0
# 20     dayeighteen        45  '2020/12/18'     90       112              NaN
# 9          DayNine        30  '2020/12/09'    109       133            195.1
# 10          DayTEN        60  '2020/12/10'     98       124            269.0
# 19     dayeighteen       450  '2020/12/18'     90       112              NaN
# 3          DayFour        45  '2020/12/04'    109       175            282.4
# 31   DAYTWENTYNINE        60  '2020/12/29'    100       132            280.0
# 4          Dayfour        45  '2020/12/04'    109       175            282.4
# 11       DayEleven        60  '2020/12/11'    103       147            329.3
# 25  daytwentythree        60  '2020/12/23'    130       101            300.0
#
#     Exercise Calories
# 28              178.0
# 20                NaN
# 9               114.0
# 10              122.0
# ...

# %%
# to get the range of records
df[10:15]
# Out:
#             Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 10       DayTEN        60  '2020/12/10'     98       124            269.0
# 11    DayEleven        60  '2020/12/11'    103       147            329.3
# 12    DayTwelve        60  '2020/12/12'    100       120            250.7
# 13    DayTwelve        60  '2020/12/12'    100       120            250.7
# 14  DayThirteen        60  '2020/12/13'    106       128            345.3
#
#     Exercise Calories
# 10              122.0
# 11              195.0
# 12              193.0
# 13              155.0
# 14              146.0

# %%
# to get partcular record
df.loc[1]
# Out:
# Day                        DAYTWO
# Duration                       60
# Date                 '2020/12/02'
# Pulse                         117
# Maxpulse                      145
# RunningCalories             479.0
# Exercise Calories           198.0
# Name: 1, dtype: object

# %%
df.loc[[1],["Date"]]
# Out:
#            Date
# 1  '2020/12/02'

# %%
df['Day'] = df['Day'].str.upper()

# %%
# to check the duplicate records
df[df.duplicated(['Day','Date','Duration'])]
# Out:
#           Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 4     DAYFOUR        45  '2020/12/04'    109       175            282.4
# 13  DAYTWELVE        60  '2020/12/12'    100       120            250.7
#
#     Exercise Calories
# 4               131.0
# 13              155.0

# %%
# to check the null values
df['Exercise Calories'].isnull()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# Name: Exercise Calories, dtype: bool

# %%
df['RunningCalories'].isnull().sum()
# Out:
# 3

# %%
# to remove null values
df.dropna()
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 4          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 5          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 6           DAYSIX        60  '2020/12/06'    102       127            300.0
# 7         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 8         DAYEIGHT       450  '2020/12/08'    104       134            253.3
# 9          DAYNINE        30  '2020/12/09'    109       133            195.1
# 10          DAYTEN        60  '2020/12/10'     98       124            269.0
# 11       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
# to remove duplicate records
df.drop_duplicates(['Day','Date'],inplace=True)

# %%
df
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         DAYTHREE        60  '2020/12/03'    103       135            340.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 5          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 6           DAYSIX        60  '2020/12/06'    102       127            300.0
# 7         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 8         DAYEIGHT       450  '2020/12/08'    104       134            253.3
# 9          DAYNINE        30  '2020/12/09'    109       133            195.1
# 10          DAYTEN        60  '2020/12/10'     98       124            269.0
# 11       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
# to find the average of running calories and excerise calories
rn = df['RunningCalories'].mean()
print(rn)
ex = df['Exercise Calories'].mean()
print(ex)
# Out:
# 306.5413793103448
# 152.53571428571428

# %%
rn = round(rn)
print(rn)
ex = round(ex)
print(ex)
# Out:
# 307
# 153

# %%
# fillna is a method to fill a particular value in null values of a column
df['RunningCalories'].fillna(rn,inplace=True)
df['Exercise Calories'].fillna(ex,inplace=True)
df
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         DAYTHREE        60  '2020/12/03'    103       135            340.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 5          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 6           DAYSIX        60  '2020/12/06'    102       127            300.0
# 7         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 8         DAYEIGHT       450  '2020/12/08'    104       134            253.3
# 9          DAYNINE        30  '2020/12/09'    109       133            195.1
# 10          DAYTEN        60  '2020/12/10'     98       124            269.0
# 11       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
# resetting the index number
df.reset_index(inplace=True)
df
# Out:
#     index             Day  Duration          Date  Pulse  Maxpulse  \
# 0       0          DAYONE        60  '2020/12/01'    110       130
# 1       1          DAYTWO        60  '2020/12/02'    117       145
# 2       2        DAYTHREE        60  '2020/12/03'    103       135
# 3       3         DAYFOUR        45  '2020/12/04'    109       175
# 4       5         DAYFIVE        45  '2020/12/05'    117       148
# 5       6          DAYSIX        60  '2020/12/06'    102       127
# 6       7        DAYSEVEN        60  '2020/12/07'    110       136
# 7       8        DAYEIGHT       450  '2020/12/08'    104       134
# 8       9         DAYNINE        30  '2020/12/09'    109       133
# 9      10          DAYTEN        60  '2020/12/10'     98       124
# 10     11       DAYELEVEN        60  '2020/12/11'    103       147
# 11     12       DAYTWELVE        60  '2020/12/12'    100       120
# 12     14     DAYTHIRTEEN        60  '2020/12/13'    106       128
# ...

# %%
df.columns
# Out:
# Index(['index', 'Day', 'Duration', 'Date', 'Pulse', 'Maxpulse',
#        'RunningCalories', 'Exercise Calories'],
#       dtype='object')

# %%
# to drop a column
df.drop(axis=1,columns='index',inplace=True)
df
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         DAYTHREE        60  '2020/12/03'    103       135            340.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 4          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 5           DAYSIX        60  '2020/12/06'    102       127            300.0
# 6         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 7         DAYEIGHT       450  '2020/12/08'    104       134            253.3
# 8          DAYNINE        30  '2020/12/09'    109       133            195.1
# 9           DAYTEN        60  '2020/12/10'     98       124            269.0
# 10       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
df
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         DAYTHREE        60  '2020/12/03'    103       135            340.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 4          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 5           DAYSIX        60  '2020/12/06'    102       127            300.0
# 6         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 7         DAYEIGHT       450  '2020/12/08'    104       134            253.3
# 8          DAYNINE        30  '2020/12/09'    109       133            195.1
# 9           DAYTEN        60  '2020/12/10'     98       124            269.0
# 10       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
# To check unique values in a column
df['Day'].unique()
# Out:
# array(['DAYONE', 'DAYTWO', 'DAYTHREE', 'DAYFOUR', 'DAYFIVE', 'DAYSIX',
#        'DAYSEVEN', 'DAYEIGHT', 'DAYNINE', 'DAYTEN', 'DAYELEVEN',
#        'DAYTWELVE', 'DAYTHIRTEEN', 'DAYFOURTEEN', 'DAYFIFTEEN',
#        'DAYSIXTEEN', 'DAYSEVENTEEN', 'DAYEIGHTEEN', 'DAYNINTHEEN',
#        'DAYTEWENTY', 'DAYTWENTYONE', 'DAYTWENTYTWO', 'DAYTWENTYTHREE',
#        'DAYTWENTYFOUR', 'DAYTWENTYFIVE', 'DAYTWENTYSIX', 'DAYTWENTYSEVEN',
#        'DAYTWENTYEIGHT', 'DAYTWENTYNINE', 'DAYTHIRTY', 'DAYTHIRTYFIRST'],
#       dtype=object)

# %%
df['Duration'].unique()
# Out:
# array([ 60,  45, 450,  30], dtype=int64)

# %%
# to know number of times a value repeated 
df['Duration'].value_counts()
# Out:
# 60     23
# 45      5
# 450     2
# 30      1
# Name: Duration, dtype: int64

# %%
# converting 450 value into 45
df.loc[17,"Duration"]
# Out:
# 450

# %%
for i in df.index:
    if df.loc[i,'Duration'] > 60:
        df.loc[i,'Duration'] = 60

# %%
df
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         DAYTHREE        60  '2020/12/03'    103       135            340.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 4          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 5           DAYSIX        60  '2020/12/06'    102       127            300.0
# 6         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 7         DAYEIGHT        60  '2020/12/08'    104       134            253.3
# 8          DAYNINE        30  '2020/12/09'    109       133            195.1
# 9           DAYTEN        60  '2020/12/10'     98       124            269.0
# 10       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
# to change a particular value
df.loc[21,"Date"] = "2020/12/22"
df.loc[25,"Date"] = "2020/12/26"

# %%
df.dtypes
# Out:
# Day                   object
# Duration               int64
# Date                  object
# Pulse                  int64
# Maxpulse               int64
# RunningCalories      float64
# Exercise Calories    float64
# dtype: object

# %%
df
# Out:
#                Day  Duration          Date  Pulse  Maxpulse  RunningCalories  \
# 0           DAYONE        60  '2020/12/01'    110       130            409.1
# 1           DAYTWO        60  '2020/12/02'    117       145            479.0
# 2         DAYTHREE        60  '2020/12/03'    103       135            340.0
# 3          DAYFOUR        45  '2020/12/04'    109       175            282.4
# 4          DAYFIVE        45  '2020/12/05'    117       148            406.0
# 5           DAYSIX        60  '2020/12/06'    102       127            300.0
# 6         DAYSEVEN        60  '2020/12/07'    110       136            374.0
# 7         DAYEIGHT        60  '2020/12/08'    104       134            253.3
# 8          DAYNINE        30  '2020/12/09'    109       133            195.1
# 9           DAYTEN        60  '2020/12/10'     98       124            269.0
# 10       DAYELEVEN        60  '2020/12/11'    103       147            329.3
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Day                          object
# Duration                      int64
# Date                 datetime64[ns]
# Pulse                         int64
# Maxpulse                      int64
# RunningCalories             float64
# Exercise Calories           float64
# dtype: object

# %%
df['Date'].dt.year.unique()
# Out:
# array([2020], dtype=int64)

# %%
# creating a custom column called total Calories
df['TotalCalories'] = df['RunningCalories'] + df['Exercise Calories']

# %%
# Creating a year colum
df['Year'] = df['Date'].dt.year

# %%
df['Month'] = df['Date'].dt.month

# %%
# to change the name of the column
df.rename(columns={"RunningCalories":"RnCalories"},inplace=True)

# %%
df.rename(columns={'Exercise Calories':"ExCalories"},inplace=True)

# %%
df
# Out:
#                Day  Duration       Date  Pulse  Maxpulse  RnCalories  \
# 0           DAYONE        60 2020-12-01    110       130       409.1
# 1           DAYTWO        60 2020-12-02    117       145       479.0
# 2         DAYTHREE        60 2020-12-03    103       135       340.0
# 3          DAYFOUR        45 2020-12-04    109       175       282.4
# 4          DAYFIVE        45 2020-12-05    117       148       406.0
# 5           DAYSIX        60 2020-12-06    102       127       300.0
# 6         DAYSEVEN        60 2020-12-07    110       136       374.0
# 7         DAYEIGHT        60 2020-12-08    104       134       253.3
# 8          DAYNINE        30 2020-12-09    109       133       195.1
# 9           DAYTEN        60 2020-12-10     98       124       269.0
# 10       DAYELEVEN        60 2020-12-11    103       147       329.3
# 11       DAYTWELVE        60 2020-12-12    100       120       250.7
# 12     DAYTHIRTEEN        60 2020-12-13    106       128       345.3
# ...

# %%
# What is sum of total calories
df['TotalCalories'].sum()
# Out:
# 14233.699999999999

# %%
df['TotalCalories'].mean()
# Out:
# 459.1516129032258

# %%
df['TotalCalories'].max()
# Out:
# 677.0

# %%
df['TotalCalories'].min()
# Out:
# 309.1

# %%
df['TotalCalories'].count()
# Out:
# 31

# %%
df['TotalCalories'].std()
# Out:
# 71.98771594731859

# %%
# query method is used to filter out the data
df.query("TotalCalories == 309.1")
# Out:
#        Day  Duration       Date  Pulse  Maxpulse  RnCalories  ExCalories  \
# 8  DAYNINE        30 2020-12-09    109       133       195.1       114.0
#
#    TotalCalories  Year  Month
# 8          309.1  2020     12

# %%
df.query("Duration == 60")
# Out:
#                Day  Duration       Date  Pulse  Maxpulse  RnCalories  \
# 0           DAYONE        60 2020-12-01    110       130       409.1
# 1           DAYTWO        60 2020-12-02    117       145       479.0
# 2         DAYTHREE        60 2020-12-03    103       135       340.0
# 5           DAYSIX        60 2020-12-06    102       127       300.0
# 6         DAYSEVEN        60 2020-12-07    110       136       374.0
# 7         DAYEIGHT        60 2020-12-08    104       134       253.3
# 9           DAYTEN        60 2020-12-10     98       124       269.0
# 10       DAYELEVEN        60 2020-12-11    103       147       329.3
# 11       DAYTWELVE        60 2020-12-12    100       120       250.7
# 12     DAYTHIRTEEN        60 2020-12-13    106       128       345.3
# 13     DAYFOURTEEN        60 2020-12-14    104       132       379.3
# 14      DAYFIFTEEN        60 2020-12-15     98       123       275.0
# 15      DAYSIXTEEN        60 2020-12-16     98       120       215.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Day            31 non-null     object
#  1   Duration       31 non-null     int64
#  2   Date           31 non-null     datetime64[ns]
#  3   Pulse          31 non-null     int64
#  4   Maxpulse       31 non-null     int64
#  5   RnCalories     31 non-null     float64
#  6   ExCalories     31 non-null     float64
#  7   TotalCalories  31 non-null     float64
#  8   Year           31 non-null     int64
#  9   Month          31 non-null     int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(1)
# memory usage: 2.5+ KB

# %%
# astype method is used to change the datatype of a column
# converting int64 datatype of a column into object datatype
df['Year'] = df['Year'].astype("object")

# %%
df['Month'] = df['Month'].astype("object")
df.dtypes
# Out:
# Day                      object
# Duration                  int64
# Date             datetime64[ns]
# Pulse                     int64
# Maxpulse                  int64
# RnCalories              float64
# ExCalories              float64
# TotalCalories           float64
# Year                     object
# Month                    object
# dtype: object

# %%
# to get the summary statistics of a dataset which contain Numerical columns
df.describe()
# Out:
#         Duration       Pulse    Maxpulse  RnCalories  ExCalories  \
# count  31.000000   31.000000   31.000000   31.000000   31.000000
# mean   56.612903  103.612903  128.774194  306.570968  152.580645
# std     7.459568    7.935899   13.119222   64.115662   30.214538
# min    30.000000   90.000000  101.000000  195.100000  100.000000
# 25%    60.000000  100.000000  120.000000  252.000000  122.000000
# 50%    60.000000  103.000000  128.000000  300.000000  153.000000
# 75%    60.000000  107.000000  132.500000  342.650000  176.000000
# max    60.000000  130.000000  175.000000  479.000000  198.000000
#
#        TotalCalories
# count      31.000000
# mean      459.151613
# std        71.987716
# min       309.100000
# 25%       418.500000
# 50%       448.000000
# 75%       492.500000
# max       677.000000

# %%
df['Duration'].value_counts()
# Out:
# 60    25
# 45     5
# 30     1
# Name: Duration, dtype: int64

# %%
df['DayNumber'] = df['Date'].dt.day

# %%
df['DayNumber'] = df['DayNumber'].astype("object")

# %%
df.dtypes
# Out:
# Day                      object
# Duration                  int64
# Date             datetime64[ns]
# Pulse                     int64
# Maxpulse                  int64
# RnCalories              float64
# ExCalories              float64
# TotalCalories           float64
# Year                     object
# Month                    object
# DayNumber                object
# dtype: object

# %%
# Importing chocolate data 
choco_df = pd.read_csv("A:/Data Anlayst Course/Datasets/cds.csv")
choco_df.head()
# Out:
#         Dates  Year     SalesPerson  Gender     Location  \
# 0  01-01-2015  2015     Mahesh Raju    Male  New Zealand
# 1  02-01-2015  2015  Siddhart Singh    Male          USA
# 2  03-01-2015  2015   Hussain Abdul    Male          USA
# 3  04-01-2015  2015  Simran Prakash  Female       Canada
# 4  05-01-2015  2015   Vishnu Advani    Male           UK
#
#                 Product  Sales  Units  CostPerUnit   M Cost  Profit/Loss
# 0        70% Dark Bites   1624    114        14.49  1651.86       -27.86
# 1  Choco Coated Almonds   6706    459         8.65  3970.35      2735.65
# 2          Almond Choco    959    147        11.88  1746.36      -787.36
# 3         Drinking Coco   9632    288         6.47  1863.36      7768.64
# 4            White Choc   2100    414        13.15  5444.10     -3344.10

# %%
choco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dates        300 non-null    object
#  1   Year         300 non-null    int64
#  2   SalesPerson  300 non-null    object
#  3   Gender       300 non-null    object
#  4   Location     300 non-null    object
#  5   Product      300 non-null    object
#  6   Sales        300 non-null    int64
#  7   Units        300 non-null    int64
#  8   CostPerUnit  300 non-null    float64
#  9   M Cost       300 non-null    float64
#  10  Profit/Loss  300 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 25.9+ KB

# %%
# to summarize the data set 
# there two types function to summarize the dataset
# groupby
# pivot_table

# %%
# total sales of each gender
choco_df.groupby("Gender")["Sales"].sum()
# Out:
# Gender
# Female    263935
# Male      976934
# Name: Sales, dtype: int64

# %%
# Location wise Total Sales
choco_df.groupby("Location")["Sales"].sum()
# Out:
# Location
# Australia      168679
# Canada         237944
# India          252469
# New Zealand    218813
# UK             173530
# USA            189434
# Name: Sales, dtype: int64

# %%
choco_df.groupby("Product")['Sales'].sum()
# Out:
# Product
# 50% Dark Bites          43183
# 70% Dark Bites          66500
# 85% Dark Bars           35378
# 99% Dark & Pure         44744
# After Nines             66283
# Almond Choco            33551
# Baker's Choco Chips     70273
# Caramel Stuffed Bars    72373
# Choco Coated Almonds    71967
# Drinking Coco           52150
# Eclairs                 63721
# Fruit & Nut Bars        56644
# Manuka Honey Choco      58009
# Milk Bars               47271
# Mint Chip Choco         62111
# Orange Choco            54712
# Organic Choco Syrup     69461
# Peanut Butter Cubes     69160
# Raspberry Choco         68971
# Smooth Sliky Salty      39263
# Spicy Special Slims     37772
# White Choc              57372
# Name: Sales, dtype: int64

# %%
# WHAT IS THE TOTAL SALES OF EACH SALES PERSON
choco_df.groupby("SalesPerson")['Sales'].sum()
# Out:
# SalesPerson
# Abhinav Sinha     106834
# Dinesh Mehta      123949
# Hussain Abdul     132580
# Mahesh Raju       151599
# Priya Ranu        165725
# Sameer Khan       149975
# Siddhart Singh     98084
# Simran Prakash     98210
# Sundar Prasad      83216
# Vishnu Advani     130697
# Name: Sales, dtype: int64

# %%
choco_df.groupby(["Location",'Gender'])['Sales'].sum()
# Out:
# Location     Gender
# Australia    Female     31290
#              Male      137389
# Canada       Female     78862
#              Male      159082
# India        Female     57414
#              Male      195055
# New Zealand  Female     31787
#              Male      187026
# UK           Female     20524
#              Male      153006
# USA          Female     44058
#              Male      145376
# Name: Sales, dtype: int64

# %%
# plot method is used to create visulaisation of the summarize data
choco_df.groupby("Gender")["Sales"].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='Sales'>

# %%
df.head()
# Out:
#         Day  Duration       Date  Pulse  Maxpulse  RnCalories  ExCalories  \
# 0    DAYONE        60 2020-12-01    110       130       409.1       169.0
# 1    DAYTWO        60 2020-12-02    117       145       479.0       198.0
# 2  DAYTHREE        60 2020-12-03    103       135       340.0       153.0
# 3   DAYFOUR        45 2020-12-04    109       175       282.4       185.0
# 4   DAYFIVE        45 2020-12-05    117       148       406.0       113.0
#
#    TotalCalories  Year Month DayNumber
# 0          578.1  2020    12         1
# 1          677.0  2020    12         2
# 2          493.0  2020    12         3
# 3          467.4  2020    12         4
# 4          519.0  2020    12         5

# %%
df.groupby("DayNumber")['TotalCalories'].sum().plot()
# Out:
# <Axes: xlabel='DayNumber'>

# %%
# Loading dataset using seaborn library
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.groupby("smoker")['total_bill'].count()
# Out:
# smoker
# Yes     93
# No     151
# Name: total_bill, dtype: int64

# %%
df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
# Time wise sum of total bill
df.groupby('time')['total_bill'].sum()
# Out:
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64

# %%
# pivot table
abc = pd.pivot_table(data=df,values="total_bill",columns='time',aggfunc='sum')
abc
# Out:
# time          Lunch  Dinner
# total_bill  1167.47  3660.3

# %%
# transpose method is used to convert the h into v
abc = abc.T

# %%
abc = abc.reset_index()
abc
# Out:
#    index    time  total_bill
# 0      0   Lunch     1167.47
# 1      1  Dinner     3660.30

# %%
abc.drop(axis=1,columns='index',inplace=True)

# %%
abc
# Out:
#      time  total_bill
# 0   Lunch     1167.47
# 1  Dinner     3660.30

# %%
abc.columns
# Out:
# Index(['time', 'total_bill'], dtype='object')

# %%
abc.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['grand_total'] = df['total_bill'] + df['tip']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  grand_total
# 0       16.99  1.01  Female     No  Sun  Dinner     2        18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3        12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3        24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2        26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4        28.20

# %%
# creating a function to categorize the grand total values
def categorize(column):
    if column < 15:
        return "Low"
    elif column >= 15 and column < 35:
        return "Medium"
    else:
        return "High"
categorize(10)
# Out:
# 'Low'

# %%
# apply method in pandas is used to apply functions on dfcolumns
df['categorize'] = df['grand_total'].apply(categorize)
df.sample(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size  grand_total  \
# 149        7.51  2.00    Male     No  Thur   Lunch     2         9.51
# 108       18.24  3.76    Male     No   Sat  Dinner     2        22.00
# 38        18.69  2.31    Male     No   Sat  Dinner     3        21.00
# 77        27.20  4.00    Male     No  Thur   Lunch     4        31.20
# 4         24.59  3.61  Female     No   Sun  Dinner     4        28.20
# 50        12.54  2.50    Male     No   Sun  Dinner     2        15.04
# 162       16.21  2.00  Female     No   Sun  Dinner     3        18.21
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2        19.89
# 148        9.78  1.73    Male     No  Thur   Lunch     2        11.51
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2        12.63
# 128       11.38  2.00  Female     No  Thur   Lunch     2        13.38
# 116       29.93  5.07    Male     No   Sun  Dinner     4        35.00
# ...

# %%
# Histogram is used to show the distribution of the data
df['grand_total'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# !pip install pandas-profiling
# Out:
# Unable to create process using 'C:\Users\Syed Rahman Hussain\AppData\Local\anaconda3\python.exe "C:\Users\Syed Rahman Hussain\AppData\Local\anaconda3\Scripts\pip-script.py" install pandas-profiling'

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  grand_total  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3        12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3        24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2        26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4        28.20
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2        19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2        21.78
#
#     categorize
# 0       Medium
# 1          Low
# 2       Medium
# 3       Medium
# 4       Medium
# ..         ...
# ...

# %%
from pandas_profiling import ProfileReport

# %%
report = ProfileReport(df)
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2024-01-16 05:22:02.528343&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
